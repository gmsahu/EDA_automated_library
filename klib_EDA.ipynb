# %% [markdown]
# <a href="https://colab.research.google.com/github/gmsahu/EDA_automated_library/blob/main/klib_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **`EDA`** with **klib**
#
# Klib library-
#
# · Helps in importing, cleaning and analyzing and preprocessing data.
# . Helps in visualizing dataset while write single code.

# %%
pip install klib

# %%
import klib
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.drop(['alone','adult_male'],axis=1,inplace=True)

# %%
klib.cat_plot(df) #shows the categorical data plot
# Out:
# GridSpec(6, 7)

# %%
klib.corr_mat(df) #shows the correlation matrix
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_11462_row0_col0, #T_11462_row0_col4, #T_11462_row0_col5, #T_11462_row1_col1, #T_11462_row1_col3, #T_11462_row1_col4, #T_11462_row2_col2, #T_11462_row2_col5, #T_11462_row3_col1, #T_11462_row3_col3, #T_11462_row3_col4, #T_11462_row3_col5, #T_11462_row4_col0, #T_11462_row4_col1, #T_11462_row4_col3, #T_11462_row4_col4, #T_11462_row4_col5, #T_11462_row5_col0, #T_11462_row5_col2, #T_11462_row5_col3, #T_11462_row5_col4, #T_11462_row5_col5 {
#   color: None;
# }
# #T_11462_row0_col1, #T_11462_row0_col2, #T_11462_row0_col3, #T_11462_row1_col0, #T_11462_row1_col2, #T_11462_row1_col5, #T_11462_row2_col0, #T_11462_row2_col1, #T_11462_row2_col3, #T_11462_row2_col4, #T_11462_row3_col0, #T_11462_row3_col2, #T_11462_row4_col2, #T_11462_row5_col1 {
# ...

# %%
klib.dist_plot(df) #shows the distribution plot
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
klib.corr_plot(df) #shows the correlation plot
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.missingval_plot(df) #shows the missing values plot
# Out:
# GridSpec(6, 6)

# %%
df_clean=klib.data_cleaning(df) #cleans the data
# Out:
# Shape of cleaned data: (784, 13) - Remaining NAs: 692
#
#
# Dropped rows: 107
#      of which 107 duplicates. (Rows (first 150 shown): [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)

# %%
df_clean.info() #standardise the column name,datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int8
#  1   pclass       784 non-null    int8
#  2   sex          784 non-null    category
#  3   age          678 non-null    float32
#  4   sibsp        784 non-null    int8
#  5   parch        784 non-null    int8
#  6   fare         784 non-null    float32
#  7   embarked     782 non-null    category
#  8   class        784 non-null    category
#  9   who          784 non-null    category
#  10  deck         202 non-null    category
#  11  embark_town  782 non-null    category
#  12  alive        784 non-null    category
# dtypes: category(7), float32(2), int8(4)
# memory usage: 15.8 KB

# %%
 klib_clean_columns=klib.clean_column_names(df)  #clean the column names

# %%
 klib_clean_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  deck         203 non-null    category
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
# dtypes: category(2), float64(2), int64(4), object(5)
# memory usage: 78.9+ KB

# %%
klib_datatype=klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()

# %%
klib_datatype.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int8
#  1   pclass       891 non-null    int8
#  2   sex          891 non-null    category
#  3   age          714 non-null    float32
#  4   sibsp        891 non-null    int8
#  5   parch        891 non-null    int8
#  6   fare         891 non-null    float32
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    category
#  10  deck         203 non-null    category
#  11  embark_town  889 non-null    category
#  12  alive        891 non-null    category
# dtypes: category(7), float32(2), int8(4)
# memory usage: 17.8 KB

# %%
df_clean.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# deck           582
# embark_town      2
# alive            0
# dtype: int64

# %%
klib_clean_missing=klib.mv_col_handling(df) #handling missing values
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:443: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_local[cols_mv] = data_local[cols_mv].applymap(lambda x: x if pd.isna(x) else 1).fillna(0)
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:449: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(corrmat[col]).nlargest(2)[1] > corr_thresh_features:
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:449: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(corrmat[col]).nlargest(2)[1] > corr_thresh_features:

# %%
klib_clean_missing.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# embark_town      2
# alive            0
# dtype: int64
